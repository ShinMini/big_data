# %% [markdown]
# # variable & data type

# %% [markdown]
# # short cut
# # shift + enter : move next cell after running
# # control + enter : run the cell and maintain

# %%
1+5
# Out:
# 6

# %%
4+5
# Out:
# 9

# %% [markdown]
# # variable

# %%
name = "홍길동" # "홍길도"이라는 값을 name 이란느 변수에 대입
# 이름이 name인 공간이 메모리에 없으면 새로 만들고 대입, 있으면 있는 공간에 대입. 
print(name) # print => name이라는 변수명을 갖는 주소값 안에 있는 value(값)을 출력하시오,

# %% [markdown]
# # 변수를 메모리에서 삭제할 수 있음.

# %%
# ex)_
age1 = 31
print(age1)
del age1
print(age1)
# Out:
# 31
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3380/1293445265.py in <module>
#       3 print(age1)
#       4 del age1
# ----> 5 print(age1)
#
# NameError: name 'age1' is not defined

# %%
# 파이썬은 정적 타입언어와 동적타입 언어 모두를 지원함, 
# 정적 타입 언어는 속도와 최적화 부분에서 유리하지만, 일정 타입을 엄격히 지켜야하는 제약이 있다. 
# 반면, 동적 타입 언어는 자유롭게 변수를 지정한뒤, 이후에 값을 설정할 수 있지만, 최적화와 에러 검출에 불리하다. 

# 정적타입언어 => 변수에 타입을 고정해서 같은 타입의 값들만 저장
# ex) 
int age = 20
age = 40 
age = 50 

age = "스무살" # 에러 발생
# Out:
#   File "C:\Users\gusal\AppData\Local\Temp/ipykernel_3380/3143966697.py", line 7
#     int age = 20
#         ^
# SyntaxError: invalid syntax

# %%
# 값과 타입을 확인하는 방법
type(age)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_3380/517639245.py in <module>
#       1 # 값과 타입을 확인하는 방법
# ----> 2 type(age)
#
# NameError: name 'age' is not defined
